# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('../data/Churn_Modelling.csv')

# %%
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %%
df.shape
# Out:
# (10000, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df = df.dropna()

# %%
df['Exited'].value_counts()
# Out:
# Exited
# 0    7963
# 1    2037
# Name: count, dtype: int64

# %%
df['Geography'].value_counts()
# Out:
# Geography
# France     5014
# Germany    2509
# Spain      2477
# Name: count, dtype: int64

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Male      5457
# Female    4543
# Name: count, dtype: int64

# %%
df = df.drop(columns=['RowNumber', 'CustomerId', 'Surname'], inplace=True)

# %%
df = pd.get_dummies(df,columns=['Geography','Gender'], drop_first=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[67], line 1
# ----> 1 df = pd.get_dummies(df,columns=['Geography','Gender'], drop_first=True)
#
# File E:\DeepLearning\.venv\lib\site-packages\pandas\core\reshape\encoding.py:227, in get_dummies(data, prefix, prefix_sep, dummy_na, columns, sparse, drop_first, dtype)
#     225     result = concat(with_dummies, axis=1)
#     226 else:
# --> 227     result = _get_dummies_1d(
#     228         data,
#     229         prefix,
#     230         prefix_sep,
#     231         dummy_na,
#     232         sparse=sparse,
#     233         drop_first=drop_first,
#     234         dtype=dtype,
#     235     )
#     236 return result
#
# File E:\DeepLearning\.venv\lib\site-packages\pandas\core\reshape\encoding.py:287, in _get_dummies_1d(data, prefix, prefix_sep, dummy_na, sparse, drop_first, dtype)
#     285 # if all NaN
#     286 if not dummy_na and len(levels) == 0:
# --> 287     return get_empty_frame(data)
#     289 codes = codes.copy()
#     290 if dummy_na:
#
# File E:\DeepLearning\.venv\lib\site-packages\pandas\core\reshape\encoding.py:282, in _get_dummies_1d.<locals>.get_empty_frame(data)
#     280     index = data.index
#     281 else:
# --> 282     index = default_index(len(data))
#     283 return DataFrame(index=index)
#
# TypeError: object of type 'NoneType' has no len()
